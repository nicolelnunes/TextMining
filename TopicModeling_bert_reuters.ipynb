# %% [markdown]
# <a href="https://colab.research.google.com/github/nicolelnunes/TextMining/blob/main/TopicModeling_bert_reuters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data = getPreprocessedText(True,True,True,True,True,True)
data = data.sample(frac=0.8)

# %%
# !pip install bertopic

# %%
from bertopic import BERTopic

# %%
topic_model = BERTopic(min_topic_size=90)
topics, probs = topic_model.fit_transform(data['document'])

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                          Name  \
# 0      -1   1287            -1_dlrs_mln_lt_oil
# 1       0   2762      0_pct_trade_billion_year
# 2       1   1580       1_lt_shares_inc_company
# 3       2    813              2_vs_net_cts_mln
# 4       3    656          3_loss_vs_profit_cts
# 5       4    374   4_dividend_record_split_cts
# 6       5    308           5_oil_opec_bpd_gold
# 7       6    252          6_div_cts_prior_qtly
# 8       7    196  7_earnings_dlrs_quarter_year
# 9       8    143  8_crude_prices_effective_bbl
# 10      9    138          9_vs_net_billion_mln
# 11     10    121      10_mln_vs_profit_billion
#
#                                        Representation  \
# 0   [dlrs, mln, lt, oil, company, vs, year, would,...
# 1   [pct, trade, billion, year, bank, tonnes, woul...
# 2   [lt, shares, inc, company, corp, dlrs, stock, ...
# 3   [vs, net, cts, mln, shr, revs, qtr, dlrs, avg,...
# 4   [loss, vs, profit, cts, net, shr, mln, revs, q...
# ...

# %%
topic_model.get_topic(0)
# Out:
# [('pct', 0.03377404618960462),
#  ('trade', 0.025187406406746857),
#  ('billion', 0.023203122050388783),
#  ('year', 0.020858262471411974),
#  ('bank', 0.020826689103532418),
#  ('tonnes', 0.020350778526008816),
#  ('would', 0.019307663848313384),
#  ('market', 0.017880061910376725),
#  ('last', 0.016765721872889057),
#  ('japan', 0.016737509495191212)]

# %% [markdown]
# # Preprocessamento todo (remover numeros, por tudo em minusculas, tokenizar, remover stop words, stemming e lemmatization)

# %%
# %matplotlib inline
topic_model.visualize_barchart(top_n_topics=15)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = getPreprocessedText(False,True,False,False,False,False)
data = data.sample(frac=0.8)

# %%
topic_model = BERTopic(min_topic_size=90)
topics, probs = topic_model.fit_transform(data['document'])

# %%
topic_model.get_topic_info()
# Out:
#    Topic  Count                             Name  \
# 0     -1     89  -1_dividend_cts_franklin_record
# 1      0   4354                  0_vs_mln_the_of
# 2      1   3461                   1_the_to_in_of
# 3      2    244            2_cts_div_qtly_record
# 4      3    230      3_dividend_cts_record_april
# 5      4    150           4_fed_dlrs_billion_the
# 6      5    102      5_split_stock_dividend_said
#
#                                       Representation  \
# 0  [dividend, cts, franklin, record, april, taxfr...
# 1  [vs, mln, the, of, dlrs, net, to, cts, and, said]
# 2     [the, to, in, of, and, said, for, pct, on, at]
# 3  [cts, div, qtly, record, prior, pay, april, se...
# 4  [dividend, cts, record, april, qtly, div, pay,...
# 5  [fed, dlrs, billion, the, federal, customer, r...
# 6  [split, stock, dividend, said, the, twoforone,...
#
#                                  Representative_Docs
# 0  [franklin ohio sets monthly payout\n  mthly di...
# ...

# %% [markdown]
# # Só com tudo em minusculas

# %%
# %matplotlib inline
topic_model.visualize_barchart(top_n_topics=15)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = getPreprocessedText(False,True,False,True,True,False)
data = data.sample(frac=0.8)

# %%
topic_model = BERTopic(min_topic_size=90)
topics, probs = topic_model.fit_transform(data['document'])

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                           Name  \
# 0      -1   1345         -1_pct_would_bank_rate
# 1       0   2521               0_vs_mln_net_cts
# 2       1   1608        1_lt_shares_inc_company
# 3       2    844  2_pct_billion_dollar_february
# 4       3    632    3_cts_record_dividend_april
# 5       4    591        4_tonnes_wheat_87_grain
# 6       5    388         5_oil_opec_bpd_barrels
# 7       6    147      6_coffee_cocoa_buffer_ico
# 8       7    143  7_trade_japan_japanese_reagan
# 9       8    108        8_stg_bank_money_market
# 10      9    107       9_crude_prices_50_barrel
# 11     10    100   10_fed_week_reserves_federal
# 12     11     96   11_strike_workers_union_port
#
#                                        Representation  \
# 0   [pct, would, bank, rate, year, trade, japan, d...
# 1   [vs, mln, net, cts, 000, loss, shr, dlrs, prof...
# 2   [lt, shares, inc, company, corp, dlrs, offer, ...
# 3   [pct, billion, dollar, february, year, bank, j...
# ...

# %% [markdown]
# # Só com o tratamento das stop words e stemming e tudo em minusculas

# %%
# %matplotlib inline
topic_model.visualize_barchart(top_n_topics=15)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
